# %% [markdown]
# # 📘 पायथन सीखें – आसान भाषा में
# ## अध्याय 2: डब्बा – वेरिएबल्स

# %% [markdown]
# ### कहानी
#
# पहले अध्याय में मोहन ने जाना कि पायथन से हम कंप्यूटर को आदेश देकर अपनी बात मनवा सकते हैं।
# लेकिन अब एक नई समस्या सामने आई।
#
# मोहन रोज़ खेत से आने वाली बोरियों का हिसाब लिखता था:
# - सोमवार: 10 बोरी
# - मंगलवार: 12 बोरी
# - बुधवार: 8 बोरी
#
# हर बार उसे नई गिनती के लिए अलग-अलग `print()` लिखना पड़ता।
# यह देखकर रवि ने कहा:
#
# > "मोहन! क्या तू हर बोरी अलग-अलग जगह रखेगा, या सबको किसी डब्बे (container) में रखेगा?"
#
# मोहन बोला:
# > "डब्बा तो बहुत काम आता है, चीज़ें संभालकर रख लेता है।"
#
# रवि ने मुस्कुराते हुए कहा:
# > "बस! प्रोग्रामिंग में भी हमें चीज़ों को **डब्बे** (Variable) में रखना होता है।"

# %% [markdown]
# ### वेरिएबल (Variable) क्या है?
#
# * वेरिएबल = डेटा रखने का डब्बा।
# * इसमें हम **संख्या**, **शब्द**, या कोई भी जानकारी रख सकते हैं।
# * जब चाहें उस डब्बे का नाम लेकर उसका मान (value) निकाल सकते हैं।
#
# 👉 ऐसे समझो: वेरिएबल = नाम + मान।

# %%
# एक डब्बा (वेरिएबल) बनाते हैं
bore_monday = 10
bore_tuesday = 12
bore_wednesday = 8

# अब इन डब्बों को प्रिंट करते हैं
print("सोमवार:", bore_monday)
print("मंगलवार:", bore_tuesday)
print("बुधवार:", bore_wednesday)

# %% [markdown]
# आउटपुट:
# ```
# सोमवार: 10
# मंगलवार: 12
# बुधवार: 8
# ```

# %% [markdown]
# ### वेरिएबल का फ़ायदा
#
# * एक ही जगह मान (value) बदलो, और पूरी गणना बदल जाएगी।
# * वेरिएबल्स से हम जोड़, घटाव, गुणा, भाग सब कर सकते हैं।
#
# जैसे, मोहन को तीन दिन का कुल हिसाब निकालना है:

# %%
# तीन दिन का कुल हिसाब
total_bore = bore_monday + bore_tuesday + bore_wednesday
print("कुल बोरी:", total_bore)

# %% [markdown]
# आउटपुट:
# ```
# कुल बोरी: 30
# ```

# %% [markdown]
# ### अभ्यास प्रश्न
#
# अब आपकी बारी! कुछ अभ्यास करके देखें:
#
# 1. अपना नाम एक वेरिएबल में रखिए और फिर `print()` करके स्क्रीन पर दिखाइए।
#
#    ```python
#    name = "राम"
#    print(name)
#    ```
#
# 2. अपनी उम्र एक वेरिएबल में रखिए और उसे 5 साल बाद की उम्र निकालकर प्रिंट कीजिए।
#
# 3. तीन विषयों के अंक (जैसे गणित, हिंदी, अंग्रेज़ी) अलग-अलग वेरिएबल्स में रखिए और उनका कुल (total) निकालिए।
#
# 4. नीचे दिए गए कोड को चलाइए और समझिए कि क्या हो रहा है:
#    ```python
#    x = 10
#    y = x
#    x = 20
#    print(y)
#    ```
#    👉 आउटपुट 10 क्यों आया? समझाइए।
#
# 5. अपनी पसंदीदा किताब, लेखक और वर्ष को तीन अलग-अलग वेरिएबल्स में रखिए और उन्हें अच्छे फ़ॉर्मेट में प्रिंट कीजिए।

# %% [markdown]
# ### सीखने योग्य बातें
#
# - वेरिएबल = डेटा रखने का डब्बा।
# - वेरिएबल का नाम साफ़-साफ़ और समझने लायक होना चाहिए (जैसे `age`, `marks`, `village_name`)।
# - वेरिएबल का मान बदलने से परिणाम भी बदल जाएगा।
# - यही आधार है आगे के बड़े प्रोग्राम्स का।

# %% [markdown]
# ---
# 🔔 **अगला अध्याय:** "गणित का जादू – ऑपरेटर्स" जहाँ हम सीखेंगे जोड़, घटाव, गुणा, भाग और बाकी सारे गणितीय कमाल।
