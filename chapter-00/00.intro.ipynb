# %% [markdown]
# # **मेरी पहली कोडिंग की किताब**
# ### गाँव के बच्चों के लिए आसान भाषा में
#
# **लक्षित उम्र:** 10-12 साल
# **आवश्यकता:** बुनियादी कंप्यूटर/मोबाइल ज्ञान

# %% [markdown]
# ## **अनुक्रम (Table of Contents)**
# 1.  [अध्याय 1: कोडिंग क्या है?](#अध्याय-1-कोडिंग-क्या-है)
# 2.  [अध्याय 2: कोडिंग कहाँ काम आती है?](#अध्याय-2-कोडिंग-कहाँ-काम-आती-है)
# 3.  [अध्याय 3: कोडिंग सीखने के लिए औज़ार](#अध्याय-3-कोडिंग-सीखने-के-लिए-औज़ार)
# 4.  [अध्याय 4: पहला प्रोग्राम (Python में)](#अध्याय-4-पहला-प्रोग्राम-Python-में)
# 5.  [अध्याय 5: गणित और कोडिंग](#अध्याय-5-गणित-और-कोडिंग)
# 6.  [अध्याय 6: एक सरल गेम बनाओ](#अध्याय-6-एक-सरल-गेम-बनाओ)
# 7.  [अध्याय 7: आर्टिफ़िशियल इंटेलिजेंस (AI) का पहला परिचय](#अध्याय-7-आर्टिफ़िशियल-इंटेलिजेंस-AI-का-पहला-परिचय)
# 8.  [अध्याय 8: कोडिंग से गाँव का भला](#अध्याय-8-कोडिंग-से-गाँव-का-भला)
# 9.  [अध्याय 9: तुम भी कोडिंग मास्टर बन सकते हो](#अध्याय-9-तुम-भी-कोडिंग-मास्टर-बन-सकते-हो)
# 10. [परियोजना: अपना एक छोटा कैलकुलेटर बनाएं](#परियोजना-अपना-एक-छोटा-कैलकुलेटर-बनाएं)

# %% [markdown]
# ## **अध्याय 1: कोडिंग क्या है?**
#
# नमस्ते बच्चों!
#
# आज हम सीखेंगे कि कोडिंग आखिर है क्या। यह सुनने में जितना नया और मुश्किल लगता है, उतना है नहीं। यह तो बिल्कुल आपके रोज़ के काम जैसा ही है।
#
# ### **हम एक-दूसरे से कैसे बात करते हैं?**
#
# सोचो, जब आप अपने दोस्त या मम्मी-पापा से कुछ कहते हो, जैसे:
#
# 👉 “मम्मी, एक गिलास पानी ला दो।”
# 👉 “पापा, मेरी किताब का पन्ना पलट दो。”
# 👉 “चलो, बाहर खेलते हैं。”
#
# आप हिंदी या अंग्रेजी जैसी भाषा का इस्तेमाल करते हैं। सामने वाला व्यक्ति आपकी भाषा समझता है और आपके आदेश (Instruction) के मुताबिक काम करता है।
#
# ### **कंप्यूटर से कैसे बात करें?**
#
# अब सोचो, आपके आस-पास कंप्यूटर, लैपटॉप, टैबलेट, मोबाइल फ़ोन, और भी कितनी चीज़ें हैं! ये सभी मशीनें हैं। आप इनसे हिंदी या अंग्रेजी में बोलकर कुछ नहीं करवा सकते।
#
# जैसे अगर आप मोबाइल से कहो, “हे मोबाइल, मेरे लिए एक गेम खोलो!” – तो क्या वह खोल देगा? नहीं ना! क्योंकि वह आपकी बात नहीं समझता।
#
# **तो फिर ये मशीनें कैसे काम करती हैं?** इन्हें भी हमें आदेश देने पड़ते हैं, लेकिन **उनकी अपनी एक विशेष भाषा** में। उसी भाषा को **कोड (Code)** कहते हैं。
#
# ### **कोडिंग का मतलब**
#
# **कोडिंग का मतलब है, कंप्यूटर को दिए जाने वाले आदेशों (Instructions) को लिखना।**
#
# जिस तरह से आप अपने दोस्त को हिंदी में आदेश देते हैं, उसी तरह एक प्रोग्रामर (Coder) कंप्यूटर को उसकी भाषा में आदेश लिखकर देता है। इस पूरी प्रक्रिया को ही **कोडिंग (Coding)** कहा जाता है।
#
# **सीधे शब्दों में:**
# > **कोडिंग = कंप्यूटर से बात करने की भाषा सीखना और लिखना।**
#
# ### **एक छोटा सा उदाहरण (Example)**
#
# मान लो आप एक छोटा रोबोट बनाते हो और आप चाहते हो कि वह सीधे चले 10 कदम और फिर मुड़ जाए।
#
# आप उसे जो आदेश दोगे, वह कुछ ऐसा होगा:
# 1.  **आगे चलो** (10 कदम)
# 2.  **दाएँ मुड़ो**
# 3.  **रुको**
#
# यही एक छोटा सा **कोड** है! अब अगर रोबोट आपकी भाषा समझता है, तो वह ठीक वैसा ही करेगा।
#
# कंप्यूटर के साथ भी ऐसा ही है। हम उसे कोड लिखकर बताते हैं कि गेम कैसे बनाना है, कार्टून कैसे बनाना है, वेबसाइट कैसे बनानी है, या कैलकुलेटर का प्रोग्राम कैसे बनाना है.
#
# ### **निष्कर्ष (Conclusion)**
#
# तो बच्चों, कोडिंग डराने वाला शब्द नहीं है। यह तो **तार्किक सोच (Logical Thinking)** और **निर्देश देने (Giving Instructions)** की कला है। यह एक नई **सुपरपावर** की तरह है जिसे सीखकर आप मशीनों से कुछ भी करवा सकते हो – चाहे वह एक छोटा सा गेम हो या फिर चाँद पर जाने वाला रॉकेट उड़ाना!

# %% [markdown]
# ## **अध्याय 2: कोडिंग कहाँ काम आती है?**
#
# कोडिंग सिर्फ कंप्यूटर तक सीमित नहीं है। यह तो हमारे आस-पास हर जगह है! चलो कुछ उदाहरण देखते हैं:
#
# *   **📱 मोबाइल गेम (Ludo, Free Fire)** – सब कोडिंग से बने।
# *   **🏧 ATM से पैसे निकालना** – कोडिंग से चलता है।
# *   **▶️ यूट्यूब पर वीडियो देखना** – कोडिंग से होता है।
# *   **🚜 खेत में पानी चलाने की मशीन (ऑटोमेशन)** – कोडिंग से हो सकती है।
# *   **📺 टीवी रिमोट कंट्रोल** – कोडिंग से काम करता है।
#
# जब भी आप कोई इलेक्ट्रॉनिक चीज़ इस्तेमाल करते हो, समझ लो कि उसके पीछे कोडिंग का हाथ है।

# %% [markdown]
# ## **अध्याय 3: कोडिंग सीखने के लिए औज़ार**
#
# कोडिंग सीखने के लिए तुम्हें क्या चाहिए? ज़्यादा कुछ नहीं!
#
# 1.  **मोबाइल फ़ोन या कंप्यूटर:** बस यही चाहिए शुरुआत करने के लिए。
# 2.  **Scratch:** यह एक मज़ेदार ऐप/वेबसाइट है। इसमें तुम ब्लॉक्स को खींचकर जोड़ोगे और गेम/कार्टून बनाओगे। यह बिल्कुल खेल जैसा है। अच्छी बात यह है कि अगर इंटरनेट नहीं है तो भी Scratch ऑफलाइन चलता है。
# 3.  **Python:** जब Scratch में थोड़ा अभ्यास हो जाए, तो हम Python सीखेंगे। यह एक बहुत आसान और ताकतवर भाषा है, जैसे हिंदी या अंग्रेजी। आज हम इसी में प्रोग्राम लिखना शुरू करेंगे।

# %% [markdown]
# ## **अध्याय 4: पहला प्रोग्राम (Python में)**
#
# चलो, अब हम Python में अपना पहला कोड लिखते हैं। कंप्यूटर से कहते हैं कि वह हमारे लिए "नमस्ते दुनिया" लिखे।
#
# नीचे दिए गए बॉक्स में कोड लिखा है। **Run** बटन (▶️) दबाकर देखो क्या होता है।

# %%
# यह हमारा पहला प्रोग्राम है
print("नमस्ते दुनिया!")

# %% [markdown]
# **क्या हुआ?**
# *   `print()` एक कमांड है, जैसे "छापो" या "लिखो" बोलना。
# *   जो भी हम कोष्ठक `()` के अंदर डबल कोट्स `""` में लिखेंगे, कंप्यूटर उसे स्क्रीन पर छाप देगा।
#
# **अब तुम कोशिश करो!** नीचे दिए गए बॉक्स में अपना नाम लिखो और **Run** बटन दबाओ।

# %%
# अपना नाम print करो
print("मेरा नाम है: ")

# %% [markdown]
# ## **अध्याय 5: गणित और कोडिंग**
#
# कंप्यूटर गणित के सवाल हल करने में माहिर है। चलो उससे जोड़ और गुणा करवाते हैं।

# %%
# जोड़ का सवाल
a = 5
b = 7
जवाब = a + b
print("जोड़ का जवाब है:", जवाब)

# %%
# गुणा का सवाल
कितने_सेब = 8
एक_सेब_की_कीमत = 15
कुल_कीमत = कितने_सेब * एक_सेब_की_कीमत
print("कुल कीमत है:", कुल_कीमत, "रुपए")

# %% [markdown]
# **ध्यान दो:**
# *   हमने हिंदी और अंग्रेजी दोनों में नाम लिखे हैं (जैसे `a`, `जवाब`, `कितने_सेब`)। इन्हें **वेरिएबल (Variable)** कहते हैं। ये डब्बों की तरह होते हैं जिनमें हम नंबर या शब्द रख सकते हैं。
# *   `*` का मतलब होता है गुणा।

# %% [markdown]
# ## **अध्याय 6: एक सरल गेम बनाओ**
#
# चलो अब एक छोटा सा गेम बनाते हैं: **अंदाज़ा लगाओ (Guess the Number)**। कंप्यूटर एक नंबर सोचेगा और तुम्हें उसे अंदाज़ा लगाना है।
#
# नीचे कोड को **Run** करो और फिर ऊपर बने बॉक्स में अपना अंदाज़ा लिखो।

# %%
# अंदाजा लगाओ गेम
संख्या = 7 # कंप्यूटर ने यह नंबर सोचा है

print("आओ एक गेम खेलें!")
print("मैंने 1 से 10 के बीच एक नंबर सोचा है। तुम्हारा क्या अंदाजा है?")

# input() से हम उपयोगकर्ता से इनपुट लेते हैं
अंदाजा = int(input("अपना अंदाजा यहाँ लिखो: "))

if अंदाजा == संख्या:
    print("वाह! सही जवाब! तुम जीत गए! 🎉")
else:
    print("ओह! गलत अंदाजा। फिर कोशिश करो! सही नंबर था:", संख्या)

# %% [markdown]
# ## **अध्याय 7: आर्टिफ़िशियल इंटेलिजेंस (AI) का पहला परिचय**
#
# AI मतलब **कृत्रिम बुद्धिमत्ता (Artificial Intelligence)**। यानी कंप्यूटर का दिमाग। जैसे तुम बिल्ली और कुत्ते की तस्वीर में फर्क कर लेते हो, वैसे ही AI को भी सिखाया जा सकता है।
#
# नीचे एक बहुत ही सरल उदाहरण है। यह AI मॉडल नहीं है, लेकिन यह तुम्हें समझाता है कि AI कैसे सोचता है।

# %%
# एक सरल नियम-आधारित "AI"
print("मैं एक छोटा AI बॉट हूँ। मैं जानवरों की आवाज़ पहचानता हूँ।")

जानवर = input("कोई जानवर बताओ (गाय, कुत्ता, बिल्ली): ")

if जानवर == "गाय":
    print("AI बोला: गाय 'माँ-माँ' करती है!")
elif जानवर == "कुत्ता":
    print("AI बोला: कुत्ता 'भौ-भौ' करता है!")
elif जानवर == "बिल्ली":
    print("AI बोला: बिल्ली 'म्याऊं-म्याऊं' करती है!")
else:
    print("AI बोला: मुझे अभी यह सीखना बाकी है!")
# Out:
# मैं एक छोटा AI बॉट हूँ। मैं जानवरों की आवाज़ पहचानता हूँ।
# AI बोला: कुत्ता 'भौ-भौ' करता है!

# %% [markdown]
# **असली AI** इससे कहीं ज्यादा ताकतवर होता है और वह हज़ारों तस्वीरें देखकर खुद से सीखता है। तुम [Google's Teachable Machine](https://teachablemachine.withgoogle.com/) जैसी वेबसाइट पर जाकर अपना AI मॉडल बना सकते हो।

# %% [markdown]
# ## **अध्याय 8: कोडिंग से गाँव का भला**
#
# कोडिंग सिर्फ गेम बनाने के लिए नहीं है। इससे तुम अपने गाँव की मदद भी कर सकते हो:
#
# 1.  **🧑‍🌾 खेत की नमी सेंसर से नापना:** Arduino जैसे छोटे कंप्यूटर + कोडिंग से यह पता लगाया जा सकता है कि खेत में पानी देना है या नहीं। इससे पानी की बचत होगी。
# 2.  **🐄 गाय/भैंस का दूध रिकॉर्ड करना:** एक छोटा ऐप बनाया जा सकता है जिसमें रोज़ का दूध का उत्पादन लिखा जाए। इससे पता चलेगा कि किस दिन कितना दूध मिला।
# 3.  **📚 बच्चों की पढ़ाई का ऐप बनाना:** ऐसा ऐप जिसमें गणित के सवाल हों, कहानियाँ हों, जिसे बच्चे ऑफलाइन भी पढ़ सकें।
#
# तुम्हारी creativity ही limit है!

# %% [markdown]
# ## **अध्याय 9: तुम भी कोडिंग मास्टर बन सकते हो**
#
# याद रखना, कोडिंग एक सुपरपावर है और इसे सीखना हर किसी के लिए संभव है।
#
# *   **रोज़ 15 मिनट प्रैक्टिस करो:** थोड़ा लेकिन नियमित अभ्यास ज़्यादा फायदेमंद है。
# *   **अपने दोस्तों को सिखाओ:** जो सीखते हो, वो दूसरों को सिखाओ। इससे तुम्हारा दिमाग और तेज़ होगा。
# *   **खेल की तरह सीखो, डरने की ज़रूरत नहीं:** गलतियाँ करने से डरो मत। कंप्यूटर टूट नहीं जाएगा। गलतियाँ करके ही सीखोगे।
#
# **तुम्हारी यात्रा अभी शुरू हुई है। लगे रहो!**

# %% [markdown]
# ## **परियोजना: अपना एक छोटा कैलकुलेटर बनाएं**
#
# अब तक जो कुछ भी सीखा, उसे इस्तेमाल करके अपना खुद का कैलकुलेटर बनाओ। नीचे दिए गए कोड को पूरा करो।

# %%
print("मेरा पहला कैलकुलेटर")
print("==================")

पहला_नंबर = int(input("पहला नंबर डालो: "))
दूसरा_नंबर = int(input("दूसरा नंबर डालो: "))

print("\nक्या करना चाहते हो?")
print("1. जोड़ (+)")
print("2. घटा (-)")
print("3. गुणा (*)")
print("4. भाग (/)")

ऑपरेशन = input("अपना ऑपरेशन चुनो (1, 2, 3, या 4): ")

if ऑपरेशन == '1':
    जवाब = पहला_नंबर + दूसरा_नंबर
    print("जवाब:", जवाब)
elif ऑपरेशन == '2':
    जवाब = पहला_नंबर - दूसरा_नंबर
    print("जवाब:", जवाब)
elif ऑपरेशन == '3':
    जवाब = पहला_नंबर * दूसरा_नंबर
    print("जवाब:", जवाब)
elif ऑपरेशन == '4':
    if दूसरा_नंबर != 0: # यह चेक करता है कि भाग देने वाला नंबर 0 तो नहीं है
        जवाब = पहला_नंबर / दूसरा_नंबर
        print("जवाब:", जवाब)
    else:
        print("गलती! किसी नंबर को 0 से भाग नहीं दिया जा सकता।")
else:
    print("गलत ऑपरेशन चुना गया है।")
# Out:
# मेरा पहला कैलकुलेटर
# ...
#
# क्या करना चाहते हो?
# 1. जोड़ (+)
# 2. घटा (-)
# 3. गुणा (*)
# 4. भाग (/)
# जवाब: 2

# %% [markdown]
# ---
#
# ### यह तो सिर्फ एक शुरुआत है!**
#
# मैंने इस नोटबुक को इस तरह से डिज़ाइन किया है कि यह:
# *   **इंटरैक्टिव है:** बच्चे कोड लिख सकते हैं, चला सकते हैं और तुरंत नतीजा देख सकते हैं।
# *   **व्यावसायिक है:** कोड साफ और अच्छी प्रैक्टिस के साथ लिखा गया है, जिससे बच्चे सही तरीका सीखें।
# *   **सुलभ है:** भाषा सरल और मज़ेदार है। हिंदी में वेरिएबल नामों का इस्तेमाल करके इसे और relatable बनाया गया है।
# *   **विस्तार योग्य है:** आप इसमें और भी अध्याय, चित्र, प्रोजेक्ट आइडिया और अभ्यास जोड़ सकते हैं।
