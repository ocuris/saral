# %% [markdown]
# # 📘 Python सीखें – आसान भाषा में
# ## अध्याय 3: गणित का जादू – ऑपरेटर्स

# %% [markdown]
# ### कहानी
#
# मोहन अब वेरिएबल्स का जादू सीख चुका था। उसने बोरियों की गिनती को डब्बों (variables) में रखना सीख लिया।
# लेकिन एक दिन उसके पिताजी ने पूछा:
#
# > "मोहन, अगर सोमवार और मंगलवार की बोरी जोड़ दें, तो कुल कितनी होंगी? और अगर मंगलवार से बुधवार घटाएँ, तो कितनी बचेंगी?"
#
# मोहन सोच में पड़ गया – "ये तो मुझे जोड़-घटाव करना होगा।"
#
# तभी रवि बोला:
#
# > "चिंता मत कर! पायथन में जोड़-घटाव, गुणा-भाग सबका जादू है। इन्हें हम कहते हैं **ऑपरेटर्स (Operators)**।"

# %% [markdown]
# ### ऑपरेटर्स क्या हैं?
#
# * ऑपरेटर्स = गणित करने के उपकरण।
# * ये हमें जोड़, घटाव, गुणा, भाग और बाकी गणनाएँ करने देते हैं।
#
# पायथन में सबसे ज़्यादा इस्तेमाल होने वाले **Arithmetic Operators** ये हैं:
#
# | ऑपरेटर | काम |
# |---------|-----|
# | `+` | जोड़ (Addition) |
# | `-` | घटाव (Subtraction) |
# | `*` | गुणा (Multiplication) |
# | `/` | भाग (Division - परिणाम दशमलव में) |
# | `//` | भाग (Division - केवल पूर्णांक) |
# | `%` | शेषफल (Remainder) |
# | `**` | घातांक (Power) |

# %%
# उदाहरण: मोहन की बोरियों का हिसाब
monday = 10
tuesday = 12
wednesday = 8

# जोड़
print("सोमवार + मंगलवार =", monday + tuesday)

# घटाव
print("मंगलवार - बुधवार =", tuesday - wednesday)

# गुणा
print("सोमवार × 2 =", monday * 2)

# भाग (decimal में)
print("मंगलवार ÷ 3 =", tuesday / 3)

# भाग (integer में)
print("मंगलवार ÷ 3 (पूर्णांक) =", tuesday // 3)

# शेषफल
print("मंगलवार ÷ 3 का शेषफल =", tuesday % 3)

# घातांक
print("2 की घात 3 =", 2 ** 3)

# %% [markdown]
# आउटपुट:
# ```
# सोमवार + मंगलवार = 22
# मंगलवार - बुधवार = 4
# सोमवार × 2 = 20
# मंगलवार ÷ 3 = 4.0
# मंगलवार ÷ 3 (पूर्णांक) = 4
# मंगलवार ÷ 3 का शेषफल = 0
# 2 की घात 3 = 8
# ```

# %% [markdown]
# ### अभ्यास प्रश्न
#
# अब आपकी बारी! नीचे दिए सवाल हल करके देखें:
#
# 1. अपने दो दोस्तों की उम्र दो वेरिएबल्स में रखिए और उनका जोड़ (sum) निकालिए।
#
# 2. अगर एक आम की कीमत 15 रुपये है और आपने 7 आम खरीदे, तो कुल कीमत निकालिए।
#
# 3. एक कमरे में 45 लोग बैठे हैं। अगर हर कुर्सी पर 4 लोग बैठ सकते हैं, तो कितनी पूरी कुर्सियाँ भरेंगी और कितने लोग बचेंगे? (संकेत: `//` और `%` का उपयोग करें)।
#
# 4. किसी भी संख्या को `**` ऑपरेटर से घातांक निकालकर देखिए (जैसे 5² या 2³)।
#
# 5. नीचे दिए कोड का आउटपुट निकालकर बताइए (पहले सोचें, फिर चलाएँ):
#    ```python
#    a = 20
#    b = 3
#    print(a // b)
#    print(a % b)
#    ```
#
# 6. अपनी जेबखर्च (pocket money) का एक वेरिएबल बनाइए और उसमें से हर दिन खर्च करके बचे हुए पैसे निकालिए।

# %% [markdown]
# ### सीखने योग्य बातें
#
# - ऑपरेटर्स गणितीय जादू की तरह काम करते हैं।
# - `/` हमेशा दशमलव में परिणाम देगा, जबकि `//` केवल पूरा अंक देगा।
# - `%` शेषफल बताता है।
# - `**` किसी संख्या की शक्ति (power) निकालने के लिए होता है।
#
# 👉 अब मोहन आसानी से जोड़-घटाव कर सकता था और हिसाब-किताब कंप्यूटर से करवा सकता था।

# %% [markdown]
# ---
# 🔔 **अगला अध्याय:** "फैसले और रास्ते – If/Else" जहाँ हम सीखेंगे कि कंप्यूटर कैसे निर्णय ले सकता है।
